# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("lady.jpg",0)
img.shape
# Out:
# (225, 225)

# %%
equalizing_img = cv2.equalizeHist(img)

plt.figure(figsize=(10,15))

plt.subplot(1,2,1)
plt.imshow(img,cmap='gray')
plt.title("Original Image.")

plt.subplot(1,2,2)
plt.imshow(equalizing_img,cmap='gray')
plt.title("Equalized Image.")
# Out:
# Text(0.5, 1.0, 'Equalized Image.')
